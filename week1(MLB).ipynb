# %% [markdown]
# <a href="https://colab.research.google.com/github/rrohanj/MLREPO/blob/main/week1(MLB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Hello World
print("Hello World, I am [Your Name]")

# 2. Arithmetic
a, b = float(input("Enter num1: ")), float(input("Enter num2: "))
print(f"Add: {a+b}, Sub: {a-b}, Mul: {a*b}, Div: {a/b}")

# 3, 4, 5, 6. Pandas Operations
df = pd.read_csv('/content/drive/MyDrive/dataset/student.csv')
print(df.head())       # First 5 rows
print(df.info())       # Dataset info
print(df.describe())   # Statistical summary

# 7. Plotting
sns.scatterplot(data=df, x='Math', y='Science')
plt.title("Math vs Science Scores")
plt.xlabel("Math"); plt.ylabel("Science")
plt.show()
# Out:
# Hello World, I am [Your Name]
# Enter num1: 5
# Enter num2: 3
# Add: 8.0, Sub: 2.0, Mul: 15.0, Div: 1.6666666666666667
#    RollNo  Math  Science  English  Gender Department
# 0       1    55       58       60    Male        CSE
# 1       2    60       63       64  Female        ECE
# 2       3    65       68       69    Male        EEE
# 3       4    70       73       74  Female        CSE
# 4       5    75       78       80    Male        ECE
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RollNo      50 non-null     int64
#  1   Math        50 non-null     int64
#  2   Science     50 non-null     int64
#  3   English     50 non-null     int64
#  4   Gender      50 non-null     object
#  5   Department  50 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB
# None
# ...
